# %% [markdown]
# <a href="https://colab.research.google.com/github/EricYsh/colab/blob/main/Cloud_hosted_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 9: Cloud-Hosted Notebook Data Manipulation

# %% [markdown]
# ## Requirements
# - Set up a cloud-hosted Jupyter Notebook (e.g., Google Colab)
# - Perform data manipulation tasks on a sample dataset
#
# The below is my Deliverables for this week's assignment.

# %% [markdown]
# # Section 1: Import Necessary Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Section 2: Load the Data

# %%
df = pd.read_csv("https://raw.githubusercontent.com/nogibjj/IDS706-MiniProject9-Cloud-Hosted-Notebook/main/data.csv")

# Display the first few rows of the data to understand its structure
df.head()
# Out:
#          Date   Product Region  Sales  Expenses  Units Sold
# 0  2022-01-01  Widget A  North    500       200          50
# 1  2022-01-01  Widget B   West    700       250          60
# 2  2022-01-02  Widget A   East    600       220          55
# 3  2022-01-02  Widget B  South    650       240          52
# 4  2022-01-03  Widget A  North    520       210          51

# %% [markdown]
# # Section 3: Basic Data Exploration

# %%
# Check for missing values
df.isnull().sum()

# Summary statistics
df.describe()
# Out:
#             Sales    Expenses  Units Sold
# count   30.000000   30.000000   30.000000
# mean   646.666667  248.000000   57.566667
# std     76.938548   23.252734    4.553766
# min    500.000000  200.000000   50.000000
# 25%    585.000000  231.250000   54.250000
# 50%    655.000000  250.000000   57.000000
# 75%    707.500000  265.000000   60.750000
# max    770.000000  290.000000   67.000000

# %% [markdown]
# # Section 4: Data Visualization

# %%
# Sales trend over time
plt.figure(figsize=(18,5))
sns.lineplot(data=df, x='Date', y='Sales', hue='Product')
plt.title('Sales Trend over Time by Product')
plt.show()

# %%
# Average sales by region
avg_sales_region = df.groupby('Region')['Sales'].mean().reset_index()
plt.figure(figsize=(12,6))
sns.barplot(data=avg_sales_region, x='Region', y='Sales', hue='Region', palette='viridis')
plt.title('Average Sales by Region')
plt.show()

# %%
# Total units sold by product
units_sold_product = df.groupby('Product')['Units Sold'].sum().reset_index()
plt.figure(figsize=(8,4))
sns.barplot(data=units_sold_product, x='Product', y='Units Sold', hue='Product', palette='magma')
plt.title('Total Units Sold by Product')
plt.show()

# %%
# Expenses trend over time
plt.figure(figsize=(18,5))
sns.lineplot(data=df, x='Date', y='Expenses', hue='Product', style='Region', dashes=False)
plt.title('Expenses Trend over Time by Product and Region')
plt.show()

# %% [markdown]
# # Section 5: Data Analysis

# %%
# Total sales by product
total_sales_product = df.groupby('Product')['Sales'].sum().reset_index()

# Most profitable day
most_profitable_day = df[df['Sales'] - df['Expenses'] == max(df['Sales'] - df['Expenses'])]

# %% [markdown]
# # Section 6: Conclusions

# %%
print(f"The product with the highest total sales is {total_sales_product.iloc[total_sales_product['Sales'].idxmax()]['Product']}.")
print(f"The most profitable day was on {most_profitable_day.iloc[0]['Date']} with a profit of {most_profitable_day.iloc[0]['Sales'] - most_profitable_day.iloc[0]['Expenses']}.")
# Out:
# The product with the highest total sales is Widget B.
# The most profitable day was on 2022-01-15 with a profit of 480.
